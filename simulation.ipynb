# %% [markdown]
# Here we want to see the results of joint porblem vs disjoint in the way that we consider management resources.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# - Topology: FatTree (k = 6)

# %%
# result is a map between number of the chains and costs of their placement
# jresult is a result of joint problem and dresult is a result of disjoint problem

jresult = {
    50: 23200,
    60: 27600,
    70: 31900,
    80: 36400,
    90: 40800,
    100: 45300,
}

dresult = {
    50: 12200,
    60: 13000,
    70: 23000,
    80: 33300,
    90: 38400,
    100: 40300,
    
}

_, ax1 = plt.subplots(figsize=(15, 15))
chains = [d for d in jresult]
jcost = [jresult[d] for d in jresult]
dcost = [dresult[d] for d in dresult]
ax1.plot(chains, jcost, 'r--', label='joint')
ax1.plot(chains, dcost, 'b', label='disjoint')
ax1.set_title('FatTree')
ax1.set(ylabel='Cost', xlabel='Chains')
ax1.legend()

# %% [markdown]
# * Topology: USnet

# %%
# result is a map between number of the chains and costs of their placement
# jresult is a result of joint problem and dresult is a result of disjoint problem

jresult = {
    50: 23500,
    60: 27500,
    70: 31400,
    80: 33500,
    90: 35800,
    100: 38700,
    130: 38900,
}

dresult = {
    50: 22500,
    60: 26000,
    70: 30000,
    80: 32000,
    90: 34400,
    100: 37500,
    130: 37800,
    
}

_, ax2 = plt.subplots(figsize=(15, 15))
chains = [d for d in jresult]
jcost = [jresult[d] for d in jresult]
dcost = [dresult[d] for d in dresult]
ax2.plot(chains, jcost, 'r--', label='joint')
ax2.plot(chains, dcost, 'b', label='disjoint')
ax2.set_title('USNet')
ax2.set(ylabel='Cost', xlabel='Chains')
ax2.legend()
